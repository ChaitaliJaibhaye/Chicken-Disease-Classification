# %%
d={"key":"Value","Key":"Value1"}

# %%
print(d)
# Out:
# {'key': 'Value', 'Key': 'Value1'}

# %%
d['key']
# Out:
# 'Value'

# %%
def get_predict(x:int, y: int) -> int:
    return x*y

# %%
get_predict(2,4)
# Out:
# 8

# %%
get_predict(2,"4")
# Out:
# '44'
